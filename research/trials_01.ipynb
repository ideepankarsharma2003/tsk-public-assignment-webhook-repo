# %%
import os; os.chdir('..')
# %pwd
# Out:
# '/home/ubuntu/tsk-public-assignment-webhook-repo'

# %%
push= {'ref': 'refs/heads/main', 'before': 'd47f15bc858bc815ebec6bb77eaa07b25d021b5a', 'after': '68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55', 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': 1719213524, 'updated_at': '2024-06-24T14:26:09Z', 'pushed_at': 1719239519, 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 11, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'stargazers': 0, 'master_branch': 'main'}, 'pusher': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'created': False, 'deleted': False, 'forced': False, 'base_ref': None, 'compare': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/d47f15bc858b...68b3640de8b9', 'commits': [{'id': '68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55', 'tree_id': 'f1e48740a50d275b638b73769bdd87b04fa9ec1e', 'distinct': True, 'message': 'first commit', 'timestamp': '2024-06-24T14:31:54Z', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55', 'author': {'name': 'Ubuntu', 'email': 'ubuntu@ip-172-31-22-198.ec2.internal'}, 'committer': {'name': 'Ubuntu', 'email': 'ubuntu@ip-172-31-22-198.ec2.internal'}, 'added': [], 'removed': ['dym', 'new'], 'modified': ['README.md']}], 'head_commit': {'id': '68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55', 'tree_id': 'f1e48740a50d275b638b73769bdd87b04fa9ec1e', 'distinct': True, 'message': 'first commit', 'timestamp': '2024-06-24T14:31:54Z', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55', 'author': {'name': 'Ubuntu', 'email': 'ubuntu@ip-172-31-22-198.ec2.internal'}, 'committer': {'name': 'Ubuntu', 'email': 'ubuntu@ip-172-31-22-198.ec2.internal'}, 'added': [], 'removed': ['dym', 'new'], 'modified': ['README.md']}}




push.keys()
# Out:
# dict_keys(['ref', 'before', 'after', 'repository', 'pusher', 'sender', 'created', 'deleted', 'forced', 'base_ref', 'compare', 'commits', 'head_commit'])

# %%
push["pusher"]
# Out:
# {'name': 'ideepankarsharma2003',
#  'email': '74599435+ideepankarsharma2003@users.noreply.github.com'}

# %%
push["commits"]
# Out:
# [{'id': '68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55',
#   'tree_id': 'f1e48740a50d275b638b73769bdd87b04fa9ec1e',
#   'distinct': True,
#   'message': 'first commit',
#   'timestamp': '2024-06-24T14:31:54Z',
#   'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/68b3640de8b981ad17f9d97a7ea5dc0dc95c8c55',
#   'author': {'name': 'Ubuntu',
#    'email': 'ubuntu@ip-172-31-22-198.ec2.internal'},
#   'committer': {'name': 'Ubuntu',
#    'email': 'ubuntu@ip-172-31-22-198.ec2.internal'},
#   'added': [],
#   'removed': ['dym', 'new'],
#   'modified': ['README.md']}]

# %%
merge= {
    'ref': 'refs/heads/ideepankarsharma2003-patch-1', 
 'before': 'e41fe7226c7c66a893e2576c84686b8092fc536e', 'after': '5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https: //avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': 1719213524, 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': 1719225815, 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'stargazers': 0, 'master_branch': 'main'}, 'pusher': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'created': False, 'deleted': False, 'forced': False, 'base_ref': None, 'compare': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/e41fe7226c7c...5565b3e0946c', 'commits': [{'id': '93b953a8f0f156101fc5a5a916dda8a02974efe5', 'tree_id': '398479f39d83fef5f187260a04a5b62787f2ebc3', 'distinct': False, 'message': 'Update README.md with new PR', 'timestamp': '2024-06-24T16:12:15+05:30', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/93b953a8f0f156101fc5a5a916dda8a02974efe5', 'author': {'name': 'Deepankar Sharma', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'username': 'ideepankarsharma2003'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'username': 'web-flow'}, 'added': [], 'removed': [], 'modified': ['README.md']}, {'id': '5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'tree_id': '398479f39d83fef5f187260a04a5b62787f2ebc3', 'distinct': True, 'message': 'Merge pull request #2 from ideepankarsharma2003/ideepankarsharma2003-patch-2\n\nUpdate README.md with new PR', 'timestamp': '2024-06-24T16:13:35+05:30', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'author': {'name': 'Deepankar Sharma', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'username': 'ideepankarsharma2003'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'username': 'web-flow'}, 'added': [], 'removed': [], 'modified': ['README.md']}], 'head_commit': {'id': '5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'tree_id': '398479f39d83fef5f187260a04a5b62787f2ebc3', 'distinct': True, 'message': 'Merge pull request #2 from ideepankarsharma2003/ideepankarsharma2003-patch-2\n\nUpdate README.md with new PR', 'timestamp': '2024-06-24T16:13:35+05:30', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'author': {'name': 'Deepankar Sharma', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'username': 'ideepankarsharma2003'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'username': 'web-flow'}, 'added': [], 'removed': [], 'modified': ['README.md']}}

# %%
import json

# %%
with open("research/merge.json", "w") as f:
    json.dump(merge, f)

# %%
closed= {'action': 'closed', 'number': 2, 'pull_request': {'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2', 'id': 1935227520, 'node_id': 'PR_kwDOMNUXkc5zWTqA', 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2', 'diff_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2.diff', 'patch_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2.patch', 'issue_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2', 'number': 2, 'state': 'closed', 'locked': False, 'title': 'Update README.md with new PR', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'created_at': '2024-06-24T10:42:45Z', 'updated_at': '2024-06-24T10:43:36Z', 'closed_at': '2024-06-24T10:43:36Z', 'merged_at': '2024-06-24T10:43:35Z', 'merge_commit_sha': '5565b3e0946cdd64bc43b1e4d4c8c91c24c64eba', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/commits', 'review_comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/comments', 'review_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2/comments', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/93b953a8f0f156101fc5a5a916dda8a02974efe5', 'head': {'label': 'ideepankarsharma2003:ideepankarsharma2003-patch-2', 'ref': 'ideepankarsharma2003-patch-2', 'sha': '93b953a8f0f156101fc5a5a916dda8a02974efe5', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, 'base': {'label': 'ideepankarsharma2003:ideepankarsharma2003-patch-1', 'ref': 'ideepankarsharma2003-patch-1', 'sha': 'e41fe7226c7c66a893e2576c84686b8092fc536e', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, '_links': {'self': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2'}, 'html': {'href': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2'}, 'issue': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2'}, 'comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2/comments'}, 'review_comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/comments'}, 'review_comment': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}'}, 'commits': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/commits'}, 'statuses': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/93b953a8f0f156101fc5a5a916dda8a02974efe5'}}, 'author_association': 'OWNER', 'auto_merge': None, 'active_lock_reason': None, 'merged': True, 'mergeable': None, 'rebaseable': None, 'mergeable_state': 'unknown', 'merged_by': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'comments': 0, 'review_comments': 0, 'maintainer_can_modify': False, 'commits': 1, 'additions': 2, 'deletions': 1, 'changed_files': 1}, 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}}
with open("research/closed.json", "w") as f:
    json.dump(closed, f)

# %%
pr= {'action': 'opened', 'number': 2, 'pull_request': {'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2', 'id': 1935227520, 'node_id': 'PR_kwDOMNUXkc5zWTqA', 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2', 'diff_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2.diff', 'patch_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2.patch', 'issue_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2', 'number': 2, 'state': 'open', 'locked': False, 'title': 'Update README.md with new PR', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'created_at': '2024-06-24T10:42:45Z', 'updated_at': '2024-06-24T10:42:45Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/commits', 'review_comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/comments', 'review_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2/comments', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/93b953a8f0f156101fc5a5a916dda8a02974efe5', 'head': {'label': 'ideepankarsharma2003:ideepankarsharma2003-patch-2', 'ref': 'ideepankarsharma2003-patch-2', 'sha': '93b953a8f0f156101fc5a5a916dda8a02974efe5', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 1, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 1, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, 'base': {'label': 'ideepankarsharma2003:ideepankarsharma2003-patch-1', 'ref': 'ideepankarsharma2003-patch-1', 'sha': 'e41fe7226c7c66a893e2576c84686b8092fc536e', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 1, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 1, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, '_links': {'self': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2'}, 'html': {'href': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/2'}, 'issue': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2'}, 'comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/2/comments'}, 'review_comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/comments'}, 'review_comment': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}'}, 'commits': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/2/commits'}, 'statuses': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/93b953a8f0f156101fc5a5a916dda8a02974efe5'}}, 'author_association': 'OWNER', 'auto_merge': None, 'active_lock_reason': None, 'merged': False, 'mergeable': None, 'rebaseable': None, 'mergeable_state': 'unknown', 'merged_by': None, 'comments': 0, 'review_comments': 0, 'maintainer_can_modify': False, 'commits': 1, 'additions': 2, 'deletions': 1, 'changed_files': 1}, 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': '2024-06-24T10:42:46Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 1, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 1, 'watchers': 0, 'default_branch': 'main'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}}
with open("research/pr.json", "w") as f:
    json.dump(pr, f)

# %%
push=  {'ref': 'refs/heads/main', 'before': '282948738cdab91d462c1b523eb0fe5f3b52acad', 'after': 'a230309f913a3eb79ca7510b07d086b81a2403e3', 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': 1719213524, 'updated_at': '2024-06-24T10:36:17Z', 'pushed_at': 1719227062, 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'stargazers': 0, 'master_branch': 'main'}, 'pusher': {'name': 'ideepankarsharma2003', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'created': False, 'deleted': False, 'forced': False, 'base_ref': None, 'compare': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/282948738cda...a230309f913a', 'commits': [{'id': 'a230309f913a3eb79ca7510b07d086b81a2403e3', 'tree_id': '1ee954729b61e909033550e1b0dc7b5e7d47b806', 'distinct': True, 'message': 'Update README.md', 'timestamp': '2024-06-24T16:34:22+05:30', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/a230309f913a3eb79ca7510b07d086b81a2403e3', 'author': {'name': 'Deepankar Sharma', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'username': 'ideepankarsharma2003'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'username': 'web-flow'}, 'added': [], 'removed': [], 'modified': ['README.md']}], 'head_commit': {'id': 'a230309f913a3eb79ca7510b07d086b81a2403e3', 'tree_id': '1ee954729b61e909033550e1b0dc7b5e7d47b806', 'distinct': True, 'message': 'Update README.md', 'timestamp': '2024-06-24T16:34:22+05:30', 'url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/commit/a230309f913a3eb79ca7510b07d086b81a2403e3', 'author': {'name': 'Deepankar Sharma', 'email': '74599435+ideepankarsharma2003@users.noreply.github.com', 'username': 'ideepankarsharma2003'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'username': 'web-flow'}, 'added': [], 'removed': [], 'modified': ['README.md']}}

with open("research/push.json", "w") as f:
    json.dump(push, f)

# %%
data= {'action': 'closed', 'number': 3, 'pull_request': {'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3', 'id': 1935305106, 'node_id': 'PR_kwDOMNUXkc5zWmmS', 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/3', 'diff_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/3.diff', 'patch_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/3.patch', 'issue_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/3', 'number': 3, 'state': 'closed', 'locked': False, 'title': 'Create dym', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'created_at': '2024-06-24T11:19:56Z', 'updated_at': '2024-06-24T11:20:05Z', 'closed_at': '2024-06-24T11:20:05Z', 'merged_at': '2024-06-24T11:20:05Z', 'merge_commit_sha': 'd4918e41956dc1a735c82bd38fffa944a51c04ff', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3/commits', 'review_comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3/comments', 'review_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/3/comments', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/16ac4f278591ff48173cb79c4098e6e4a4fca6bc', 'head': {'label': 'ideepankarsharma2003:dev', 'ref': 'dev', 'sha': '16ac4f278591ff48173cb79c4098e6e4a4fca6bc', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T11:04:25Z', 'pushed_at': '2024-06-24T11:19:57Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, 'base': {'label': 'ideepankarsharma2003:main', 'ref': 'main', 'sha': 'a230309f913a3eb79ca7510b07d086b81a2403e3', 'user': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'repo': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T11:04:25Z', 'pushed_at': '2024-06-24T11:19:57Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main', 'allow_squash_merge': True, 'allow_merge_commit': True, 'allow_rebase_merge': True, 'allow_auto_merge': False, 'delete_branch_on_merge': False, 'allow_update_branch': False, 'use_squash_pr_title_as_default': False, 'squash_merge_commit_message': 'COMMIT_MESSAGES', 'squash_merge_commit_title': 'COMMIT_OR_PR_TITLE', 'merge_commit_message': 'PR_TITLE', 'merge_commit_title': 'MERGE_MESSAGE'}}, '_links': {'self': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3'}, 'html': {'href': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo/pull/3'}, 'issue': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/3'}, 'comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/3/comments'}, 'review_comments': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3/comments'}, 'review_comment': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/comments{/number}'}, 'commits': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls/3/commits'}, 'statuses': {'href': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/16ac4f278591ff48173cb79c4098e6e4a4fca6bc'}}, 'author_association': 'OWNER', 'auto_merge': None, 'active_lock_reason': None, 'merged': True, 'mergeable': None, 'rebaseable': None, 'mergeable_state': 'unknown', 'merged_by': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'comments': 0, 'review_comments': 0, 'maintainer_can_modify': False, 'commits': 1, 'additions': 1, 'deletions': 0, 'changed_files': 1}, 'repository': {'id': 819271569, 'node_id': 'R_kgDOMNUXkQ', 'name': 'tsk-public-assignment-action-repo', 'full_name': 'ideepankarsharma2003/tsk-public-assignment-action-repo', 'private': False, 'owner': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo', 'forks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/forks', 'keys_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/teams', 'hooks_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/hooks', 'issue_events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/events', 'assignees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/tags', 'blobs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/languages', 'stargazers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/stargazers', 'contributors_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contributors', 'subscribers_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscribers', 'subscription_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/subscription', 'commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/merges', 'archive_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/downloads', 'issues_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/labels{/name}', 'releases_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/releases{/id}', 'deployments_url': 'https://api.github.com/repos/ideepankarsharma2003/tsk-public-assignment-action-repo/deployments', 'created_at': '2024-06-24T07:18:44Z', 'updated_at': '2024-06-24T11:04:25Z', 'pushed_at': '2024-06-24T11:19:57Z', 'git_url': 'git://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'ssh_url': 'git@github.com:ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'clone_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo.git', 'svn_url': 'https://github.com/ideepankarsharma2003/tsk-public-assignment-action-repo', 'homepage': None, 'size': 0, 'stargazers_count': 0, 'watchers_count': 0, 'language': None, 'has_issues': True, 'has_projects': True, 'has_downloads': True, 'has_wiki': True, 'has_pages': False, 'has_discussions': False, 'forks_count': 0, 'mirror_url': None, 'archived': False, 'disabled': False, 'open_issues_count': 0, 'license': None, 'allow_forking': True, 'is_template': False, 'web_commit_signoff_required': False, 'topics': [], 'visibility': 'public', 'forks': 0, 'open_issues': 0, 'watchers': 0, 'default_branch': 'main'}, 'sender': {'login': 'ideepankarsharma2003', 'id': 74599435, 'node_id': 'MDQ6VXNlcjc0NTk5NDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/74599435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ideepankarsharma2003', 'html_url': 'https://github.com/ideepankarsharma2003', 'followers_url': 'https://api.github.com/users/ideepankarsharma2003/followers', 'following_url': 'https://api.github.com/users/ideepankarsharma2003/following{/other_user}', 'gists_url': 'https://api.github.com/users/ideepankarsharma2003/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ideepankarsharma2003/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ideepankarsharma2003/subscriptions', 'organizations_url': 'https://api.github.com/users/ideepankarsharma2003/orgs', 'repos_url': 'https://api.github.com/users/ideepankarsharma2003/repos', 'events_url': 'https://api.github.com/users/ideepankarsharma2003/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ideepankarsharma2003/received_events', 'type': 'User', 'site_admin': False}}


'pull_request' in data and data['pull_request']['merged']
# Out:
# True
